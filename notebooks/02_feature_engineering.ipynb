# %% [markdown]
# # Feature Engineering & Analysis
#
# Simulate sliding window aggregations and feature importance.

# %%
import pandas as pd
import shap
import xgboost as xgb

# Load data
# Compute velocity features offline using pandas rolling windows
